# %% [markdown]
# # Despeckle script
#
# - This notebook preprocesses raw sentinel-1 data with a magic transform (see report) and despeckles it with the SAR2SAR algorithm.
# - The SAR2SAR script we used can be found here (https://gitlab.telecom-paris.fr/ring/sar2sar/-/tree/master/), it is not included in this repository for license reasons (use GRD version)
#
# ## To run the script
# - Select year and resolution in cell below and call despeckle() function to run the script
# - Denoising a single eo-patch takes about 15 minutes
# - The results are stored in despeckle_{chosen_year} with the same folder structure as the data downloaded from sentinelhub is
# - Both a Single threaded and a multicore version was created, the single threaded version is in general more stable but really slow, the parallelized version is fast but crashes frequently and need constant maintenance.
# - The results will appear in despeckle_sar2sarV3_res_11m (with SELECTED

# %%
SELECTED_YEARS = [2019]
SELECTED_RES = 11
WHOLE_YEAR = False #Whole year was added so we could put these files in a different folder

# %%
import os
import glob
import numpy as np
import re
import matplotlib.pyplot as plt
import shutil
import concurrent.futures

import subprocess

from util_paths import SENTINEL_1_11x11_PATH

# %%
#Cell for cleaning tmp data
for path in glob.glob(os.path.join(os.getcwd(), "despeckle_tmp*")):
    shutil.rmtree(path)

# %%
#Find folder for selected years and resolution
SENT_1_MAIN_FOLDER = SENTINEL_1_11x11_PATH
SENT_1_YEAR_FOLDERS = {}
DESPECKLE_FINAL_FOLDERS = {}
if not WHOLE_YEAR:
    DESPECKLE_FINAL_RES_FOLDER = os.path.join(os.getcwd(), f"despeckle_sar2sarV3_res_{SELECTED_RES}m")

    for year in SELECTED_YEARS:
        SENT_1_YEAR_FOLDERS[year] = os.path.join(SENT_1_MAIN_FOLDER, f"res_{SELECTED_RES}m", f"{year}")
        DESPECKLE_FINAL_FOLDERS[year] = os.path.join(DESPECKLE_FINAL_RES_FOLDER, f"{year}")

    DESPECKLE_TMP_FOLDER = os.path.join(os.getcwd(), "despeckle_tmp")
    DESPECKLE_TMP_RESULTS_FOLDER = os.path.join(os.getcwd(), "despeckle_tmp_results")
if WHOLE_YEAR:
    DESPECKLE_FINAL_RES_FOLDER = os.path.join(os.getcwd(), f"despeckle_sar2sarV3_whole_year_res_{SELECTED_RES}m")
    for year in SELECTED_YEARS:
        SENT_1_YEAR_FOLDERS[year] = os.path.join(SENT_1_MAIN_FOLDER,'whole_year',f"{year}")
        DESPECKLE_FINAL_FOLDERS[year] = os.path.join(DESPECKLE_FINAL_RES_FOLDER, f"{year}")
    DESPECKLE_TMP_FOLDER = os.path.join(os.getcwd(), "despeckle_tmp")
    DESPECKLE_TMP_RESULTS_FOLDER = os.path.join(os.getcwd(), "despeckle_tmp_results")

# %%
#The treshholding and log transform happens here
# - matrix: 2D matrix for a single time stamp and chosen polarization (0 or 1)
def old_preprocess_log_tresh(matrix, polarization):
    #matrix[matrix>1] = 1                           # Treshhold
    if polarization == 0:                           # Decibel transform with magic numbers which gave good results
        matrix = np.abs( 40*np.log10(0.5*matrix) )  # The idea behind the numbers is that they introduce some more dynamic range between 0 to 255
    else:                                           # which the model seems to like
        matrix = np.abs( 40*np.log10(4*matrix) )
    matrix[np.isinf(matrix)] = 255                  # Remove inf values (this is a result of using log on 0)
    matrix[matrix>255] = 255                        # Second treshhold since model seem to be wanting numbers between 0 to 255
    return matrix

def preprocess_transform(matrix, polarization):
    if polarization == 0:                                      
        log_base = 1.8                                        # Choose log base which gives good denoising results
        matrix =  20*np.log(50*2*matrix + 2)/np.log(log_base) # Compute log transform and do final scaling to match sar2sar examples
    else:                                         
        log_base = 1.8
        matrix =  20*np.log(50*10*matrix + 2)/np.log(log_base) 
    matrix[np.isinf(matrix)] = 100
    return matrix

# %%
#Given a path to a patch and where to store despeckling results
# - extract raw data into single numpy matrices in despeckle_tmp folder
# - preprocess by logtransform and tresholding
# - use sar2sar script and put results in despeckle_tmp_results folder
# - reconstruct the radar tensor and save in final_result_path
# - remove all tmp data
def despeckle_eo_patch(eo_patch_raw_matrix_path, final_matrix_path, sar2sar_stride = 32):
    
    #Make sure required folders exist
    if not os.path.exists(DESPECKLE_TMP_FOLDER):
        os.mkdir(DESPECKLE_TMP_FOLDER)
        
    if not os.path.exists(DESPECKLE_TMP_RESULTS_FOLDER):
        os.mkdir(DESPECKLE_TMP_RESULTS_FOLDER)
    
    #Extract raw data into despeckle_tmp folder
    raw_radar_tensor = np.load(eo_patch_raw_matrix_path)
    radar_tensor_shape = raw_radar_tensor.shape
    n_timepoints = raw_radar_tensor.shape[0]
    n_polarizations = raw_radar_tensor.shape[3]
    for t in range(n_timepoints):
        for p in range(n_polarizations):
            extracted_matrix = preprocess_transform(raw_radar_tensor[t,:,:,p], p)
            extracted_matrix_path = os.path.join(DESPECKLE_TMP_FOLDER, f"t{t}_p{p}.npy")
            np.save(extracted_matrix_path, extracted_matrix)
    
    #Run sar2sar script
    # !python sar2sar_tf2/content/SAR2SAR-GRD-test/main.py --test_data {DESPECKLE_TMP_FOLDER} --test_dir {DESPECKLE_TMP_RESULTS_FOLDER} --stride_size={sar2sar_stride}
    
    #Reconstruct original radar tensor
    denoised_radar_tensor = np.zeros(shape = radar_tensor_shape)
    denoised_matrix_paths = glob.glob(os.path.join(DESPECKLE_TMP_RESULTS_FOLDER, "*"))
    pattern = r"denoised_t(\d+)_p(\d).npy"
    for path in denoised_matrix_paths:
        t, p = re.search(pattern, path).groups()
        t = int(t)
        p = int(p)
        denoised_radar_tensor[t,:,:,p] = np.load(path)
    
    np.save(final_matrix_path, denoised_radar_tensor)
    
    #Remove all tmp files after reconstruction
    for path in glob.glob(os.path.join(DESPECKLE_TMP_FOLDER, "*")):
        os.remove(path)
    for path in denoised_matrix_paths:
        os.remove(path)

# %%
#Given a year path, find all corresponding eo-patches paths, decide where to put the results and despeckle them
def despeckle_year(year, sar2sar_stride = 32, verbose = False):
    eo_patch_paths = glob.glob(SENT_1_YEAR_FOLDERS[year] + '/*')
    print(f"########## Despeckling year {year} #############")
    for eo_patch_path in eo_patch_paths:
        #Extract patch id and find path of the raw matrix
        eo_patch_id = int(re.search(r'.eopatch_(\d+)', eo_patch_path).group(1))
        eo_patch_raw_matrix_path = os.path.join( eo_patch_path , 'data' , 'IW.npy')
        
        #Construct all neccessary folder structure for a single year
        final_eo_patch_path = os.path.join(DESPECKLE_FINAL_FOLDERS[year], f"eopatch_{eo_patch_id}")
        final_eo_patch_data_path = os.path.join(final_eo_patch_path, "data")
        final_matrix_path = os.path.join( final_eo_patch_data_path, "IW.npy")
        
        if not os.path.exists(final_eo_patch_path):
            os.mkdir(final_eo_patch_path)
        if not os.path.exists(final_eo_patch_data_path):
            os.mkdir(final_eo_patch_data_path)
        
        #Help prints for debugging this function
        if verbose:
            print(eo_patch_id)
            print(eo_patch_path)
            print(eo_patch_raw_matrix_path) 
            print()
            print(final_eo_patch_path)
            print(final_eo_patch_data_path)
            print(final_matrix_path)
            
        print(f"########## Despeckling eo-patch {eo_patch_id} #########")
            
        #Copy metadata from raw data folder into despeckled folder
        shutil.copy2(os.path.join(eo_patch_path, "bbox.geojson"), os.path.join(final_eo_patch_path, "bbox.geojson"))
        shutil.copy2(os.path.join(eo_patch_path, "meta_info.json"), os.path.join(final_eo_patch_path, "meta_info.json"))
        shutil.copy2(os.path.join(eo_patch_path, "timestamp.json"), os.path.join(final_eo_patch_path, "timestamp.json"))
            
        despeckle_eo_patch(eo_patch_raw_matrix_path, final_matrix_path, sar2sar_stride=sar2sar_stride)

# %%
def despeckle(sar2sar_stride = 32):
    for year in SELECTED_YEARS:
        if not os.path.exists(DESPECKLE_FINAL_RES_FOLDER):
            os.mkdir(DESPECKLE_FINAL_RES_FOLDER)
        if not os.path.exists(DESPECKLE_FINAL_FOLDERS[year]):
            os.mkdir(DESPECKLE_FINAL_FOLDERS[2020])
        despeckle_year(year, sar2sar_stride=sar2sar_stride)

# %% [markdown]
# # Parallelizing
#
# ### Second warning: This is extremely unstable and needs constant maintenance and restarts for unknown reasons

# %%
def handle_eo_patch_conc(args):
    
    #We check if the final matrix already exists, in which case we just ignore this job (This is to restart after crash or notebook shutdown)
    if os.path.exists(args["final_matrix_path"]):
        print(f"year {args['year']}, eopatch_{args['eo_patch_id']} already exist, skipping \n")
        return
    else:
        print(f"Despeckling year {args['year']}, eopatch {args['eo_patch_id']} \n")
    
    #Setup required folder structure
    if not os.path.exists(args["final_eo_patch_path"]):
        os.mkdir(args["final_eo_patch_path"])
    if not os.path.exists(args["final_eo_patch_data_path"]):
        os.mkdir(args["final_eo_patch_data_path"])
    if not os.path.exists(args["despeckle_tmp_folder"]):
        os.mkdir(args["despeckle_tmp_folder"])
    if not os.path.exists(args["despeckle_tmp_result_folder"]):
        os.mkdir(args["despeckle_tmp_result_folder"])
    
    for path in glob.glob(os.path.join(args["despeckle_tmp_folder"], "*")):
        os.remove(path)
    for path in glob.glob(os.path.join(args["despeckle_tmp_result_folder"], "*")):
        os.remove(path)
    
    #Copy metadata 
    shutil.copy2(os.path.join(args["eo_patch_path"], "bbox.geojson"), os.path.join(args["final_eo_patch_path"], "bbox.geojson"))
    shutil.copy2(os.path.join(args["eo_patch_path"], "meta_info.json"), os.path.join(args["final_eo_patch_path"], "meta_info.json"))
    shutil.copy2(os.path.join(args["eo_patch_path"], "timestamp.json"), os.path.join(args["final_eo_patch_path"], "timestamp.json"))
    
    #Extract raw data into despeckle_tmp folder
    raw_radar_tensor = np.load(args["eo_patch_raw_matrix_path"])
    radar_tensor_shape = raw_radar_tensor.shape
    n_timepoints = raw_radar_tensor.shape[0]
    n_polarizations = raw_radar_tensor.shape[3]
    for t in range(n_timepoints):
        for p in range(n_polarizations):
            extracted_matrix = preprocess_transform(raw_radar_tensor[t,:,:,p], p)
            extracted_matrix_path = os.path.join(args["despeckle_tmp_folder"], f"t{t}_p{p}.npy")
            np.save(extracted_matrix_path, extracted_matrix)
    
    #Run sar2sar script and wait for result
    # !python sar2sar_tf2/content/SAR2SAR-GRD-test/main.py \
        --test_data {args["despeckle_tmp_folder"]} \
        --test_dir {args["despeckle_tmp_result_folder"]} \
        --stride_size={args["sar2sar_stride"]} \
        --use_gpu 1 \
        --gpu_memory_fraction {args['gpu_memory_fraction']} 
    
    
    #Reconstruct original radar tensor with denoised data
    denoised_radar_tensor = np.zeros(shape = radar_tensor_shape)
    denoised_matrix_paths = glob.glob(os.path.join(args["despeckle_tmp_result_folder"], "*"))
    pattern = r"denoised_t(\d+)_p(\d).npy"
    for path in denoised_matrix_paths:
        t, p = re.search(pattern, path).groups()
        t = int(t)
        p = int(p)
        denoised_radar_tensor[t,:,:,p] = np.load(path)
        
    np.save(args["final_matrix_path"], denoised_radar_tensor)
    
    #Remove all tmp files after reconstruction
    #for path in glob.glob(os.path.join(args["despeckle_tmp_folder"], "*")):
    #    os.remove(path)
    #for path in denoised_matrix_paths:
    #    os.remove(path)
    if os.path.exists(args["despeckle_tmp_folder"]):
        os.remove(args["despeckle_tmp_folder"])
    if os.path.exists(args["despeckle_tmp_result_folder"]):
        os.remove(args["despeckle_tmp_result_folder"])

# %%
def despeckle_conc(n_workers = 4, sar2sar_stride = 32):
    total_gpu_memory_usage = 0.9
    memory_per_worker = total_gpu_memory_usage/n_workers
    
    args_list = []
    for year in SELECTED_YEARS:
        if not os.path.exists(DESPECKLE_FINAL_RES_FOLDER):
            os.mkdir(DESPECKLE_FINAL_RES_FOLDER)
        if not os.path.exists(DESPECKLE_FINAL_FOLDERS[year]):
            os.mkdir(DESPECKLE_FINAL_FOLDERS[year])
        for eo_patch_path in glob.glob(os.path.join(SENT_1_YEAR_FOLDERS[year], "*")):
            
            eo_patch_id = int(re.search(r'.eopatch_(\d+)', eo_patch_path).group(1))
            
            args = {}
            args["year"] = year
            args["eo_patch_id"] = eo_patch_id
            args["eo_patch_path"] = eo_patch_path
            args["eo_patch_raw_matrix_path"] = os.path.join(eo_patch_path, "data", "IW.npy")
            args["final_eo_patch_path"] = os.path.join(DESPECKLE_FINAL_FOLDERS[year], f"eopatch_{eo_patch_id}")
            args["final_eo_patch_data_path"] = os.path.join(args["final_eo_patch_path"], "data")
            args["final_matrix_path"] = os.path.join(args["final_eo_patch_data_path"], "IW.npy")
            args["sar2sar_stride"] = sar2sar_stride
            
            args["despeckle_tmp_folder"] = os.path.join(os.getcwd(), f"despeckle_tmp_{year}_{eo_patch_id}")
            args["despeckle_tmp_result_folder"] = os.path.join(os.getcwd(), f"despeckle_tmp_result_{year}_{eo_patch_id}")
            args["gpu_memory_fraction"] = memory_per_worker
            
            args_list.append(args)
            
    with concurrent.futures.ProcessPoolExecutor(max_workers=n_workers) as executor:
        executor.map(handle_eo_patch_conc, args_list)
        #for args in args_list:
        #    print(f"Starting year: {args['year']}, eopatch: {args['eo_patch_id']}")
        #    executor.submit(handle_eo_patch_conc, args)
        #executor.shutdown(wait = True)

# %%
despeckle_conc(n_workers=4)
# Out:
# year 2019, eopatch_42 already exist, skipping
# year 2019, eopatch_43 already exist, skipping
# year 2019, eopatch_117 already exist, skipping
#
#
#
# Despeckling year 2019, eopatch 78
# year 2019, eopatch_79 already exist, skipping
#
#
# year 2019, eopatch_77 already exist, skipping
# <ipython-input-5-59a87a6b8a22>:19: RuntimeWarning: invalid value encountered in log
#   matrix =  20*np.log(50*10*matrix + 2)/np.log(log_base)
# <ipython-input-5-59a87a6b8a22>:16: RuntimeWarning: invalid value encountered in log
#   matrix =  20*np.log(50*2*matrix + 2)/np.log(log_base) # Compute log transform and do final scaling to match sar2sar examples
# 2022-10-24 09:24:00.931553: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-24 09:24:07.356349: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcuda.so.1
# 2022-10-24 09:24:07.664090: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1733] Found device 0 with properties:
# pciBusID: 0000:4b:00.0 name: NVIDIA A100-SXM4-40GB computeCapability: 8.0
# coreClock: 1.41GHz coreCount: 108 deviceMemorySize: 39.41GiB deviceMemoryBandwidth: 1.41TiB/s
# 2022-10-24 09:24:07.664631: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-24 09:24:07.675182: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-10-24 09:24:07.675306: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# 2022-10-24 09:24:07.679829: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcufft.so.10
# 2022-10-24 09:24:07.682466: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcurand.so.10
# 2022-10-24 09:24:07.690507: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusolver.so.11
# 2022-10-24 09:24:07.694057: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcusparse.so.11
# 2022-10-24 09:24:07.698306: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-10-24 09:24:07.701777: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1871] Adding visible gpu devices: 0
# 2022-10-24 09:24:07.702329: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# 2022-10-24 09:24:08.612509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1258] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2022-10-24 09:24:08.612543: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1264]      0
# 2022-10-24 09:24:08.612552: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1277] 0:   N
# 2022-10-24 09:24:08.616470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1418] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 9079 MB memory) -> physical GPU (device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:4b:00.0, compute capability: 8.0)
# /apps/Arch/software/TensorFlow/2.5.0-fosscuda-2020b/lib/python3.8/site-packages/tensorflow/python/keras/legacy_tf_layers/convolutional.py:414: UserWarning: `tf.layers.conv2d` is deprecated and will be removed in a future version. Please Use `tf.keras.layers.Conv2D` instead.
#   warnings.warn('`tf.layers.conv2d` is deprecated and '
# /apps/Arch/software/TensorFlow/2.5.0-fosscuda-2020b/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# 2022-10-24 09:24:09.079527: I tensorflow/core/platform/profile_utils/cpu_utils.cc:114] CPU Frequency: 2000000000 Hz
# [*] Initialize model successfully...
# [*] Start testing on real data. Working directory: /mimer/NOBACKUP/groups/snic2022-23-428/Christoffer/Despeckle. Collecting data from /mimer/NOBACKUP/groups/snic2022-23-428/Christoffer/Despeckle/despeckle_tmp_2019_78 and storing test results in /mimer/NOBACKUP/groups/snic2022-23-428/Christoffer/Despeckle/despeckle_tmp_result_2019_78
# WARNING:tensorflow:From /apps/Arch/software/TensorFlow/2.5.0-fosscuda-2020b/lib/python3.8/site-packages/tensorflow/python/util/tf_should_use.py:247: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# [*] Reading checkpoint...
#  [*] Load weights SUCCESS...
# [*] start testing...
# 2022-10-24 09:24:09.468755: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudnn.so.8
# 2022-10-24 09:24:10.395761: I tensorflow/stream_executor/cuda/cuda_dnn.cc:359] Loaded cuDNN version 8004
# 2022-10-24 09:24:12.641930: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublas.so.11
# 2022-10-24 09:24:13.311022: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcublasLt.so.11
# Denoised image t53_p0.npy
# Denoised image t217_p1.npy
# Denoised image t215_p1.npy
# Denoised image t265_p0.npy
# Denoised image t31_p0.npy
# Denoised image t158_p1.npy
# Denoised image t261_p0.npy
# Denoised image t26_p0.npy
# Denoised image t16_p0.npy
# Denoised image t210_p1.npy
# Denoised image t219_p1.npy
# Denoised image t24_p0.npy
# Denoised image t55_p0.npy
# Denoised image t156_p0.npy
# Denoised image t32_p1.npy
# Denoised image t53_p1.npy
# Denoised image t142_p1.npy
# Denoised image t96_p0.npy
# Denoised image t94_p1.npy
# Denoised image t87_p0.npy
# Denoised image t141_p1.npy
# Denoised image t8_p1.npy
# Denoised image t18_p0.npy
# Denoised image t43_p1.npy
# Denoised image t139_p1.npy
# Denoised image t32_p0.npy
# Denoised image t84_p0.npy
# Denoised image t89_p1.npy
# Denoised image t224_p0.npy
# Denoised image t233_p1.npy
# Denoised image t108_p0.npy
# Denoised image t120_p0.npy
# Denoised image t199_p1.npy
# Denoised image t241_p0.npy
# Denoised image t264_p1.npy
# Denoised image t38_p0.npy
# Denoised image t88_p1.npy
# Denoised image t164_p0.npy
# Denoised image t110_p1.npy
# Denoised image t214_p1.npy
# Denoised image t200_p0.npy
# Denoised image t253_p1.npy
# Denoised image t73_p1.npy
# Denoised image t33_p0.npy
# Denoised image t222_p1.npy
# Denoised image t54_p0.npy
# Denoised image t129_p1.npy
# Denoised image t189_p1.npy
# Denoised image t258_p0.npy
# Denoised image t209_p0.npy
# Denoised image t83_p0.npy
# Denoised image t0_p0.npy
# Denoised image t40_p0.npy
# Denoised image t169_p0.npy
# Denoised image t17_p0.npy
# Denoised image t11_p0.npy
# Denoised image t166_p0.npy
# Denoised image t177_p0.npy
# Denoised image t131_p0.npy
# Denoised image t45_p1.npy
# Denoised image t25_p0.npy
# Denoised image t172_p1.npy
# Denoised image t176_p0.npy
# Denoised image t261_p1.npy
# Denoised image t163_p1.npy
# Denoised image t22_p0.npy
# Denoised image t149_p1.npy
# Denoised image t136_p0.npy
# Denoised image t150_p1.npy
# Denoised image t61_p0.npy
# Denoised image t238_p1.npy
# Denoised image t263_p0.npy
# Denoised image t64_p0.npy
# Denoised image t265_p1.npy
# Denoised image t28_p0.npy
# Denoised image t218_p0.npy
# Denoised image t97_p1.npy
# Denoised image t183_p1.npy
# Denoised image t157_p0.npy
# Denoised image t64_p1.npy
# Denoised image t250_p1.npy
# Denoised image t19_p0.npy
# Denoised image t168_p1.npy
# Denoised image t73_p0.npy
# Denoised image t36_p0.npy
# Denoised image t143_p0.npy
# Denoised image t171_p1.npy
# Denoised image t187_p1.npy
# Denoised image t75_p1.npy
# Denoised image t190_p0.npy
# Denoised image t132_p1.npy
# Denoised image t41_p0.npy
# Denoised image t77_p1.npy
# Denoised image t120_p1.npy
# Denoised image t198_p1.npy
# Denoised image t144_p0.npy
# Denoised image t179_p1.npy
# Denoised image t232_p0.npy
# Denoised image t256_p1.npy
# Denoised image t75_p0.npy
# Denoised image t167_p0.npy
# Denoised image t251_p0.npy
# Denoised image t186_p1.npy
# Denoised image t93_p1.npy
# Denoised image t29_p1.npy
# Denoised image t47_p1.npy
# Denoised image t10_p1.npy
# Denoised image t163_p0.npy
# Denoised image t77_p0.npy
# Denoised image t197_p0.npy
# Denoised image t129_p0.npy
# Denoised image t13_p1.npy
# Denoised image t227_p1.npy
# Denoised image t104_p1.npy
# Denoised image t62_p0.npy
# Denoised image t34_p1.npy
# Denoised image t262_p0.npy
# Denoised image t115_p1.npy
# Denoised image t7_p0.npy
# Denoised image t35_p0.npy
# Denoised image t156_p1.npy
# Denoised image t92_p0.npy
# Denoised image t254_p0.npy
# Denoised image t169_p1.npy
# Denoised image t37_p0.npy
# Denoised image t79_p0.npy
# Denoised image t85_p0.npy
# Denoised image t27_p0.npy
# Denoised image t195_p0.npy
# Denoised image t92_p1.npy
# Denoised image t142_p0.npy
# Denoised image t101_p1.npy
# Denoised image t185_p0.npy
# Denoised image t226_p1.npy
# Denoised image t14_p0.npy
# Denoised image t231_p1.npy
# Denoised image t99_p0.npy
# Denoised image t147_p1.npy
# Denoised image t10_p0.npy
# Denoised image t244_p0.npy
# Denoised image t44_p1.npy
# Denoised image t180_p1.npy
# Denoised image t110_p0.npy
# Denoised image t257_p0.npy
# Denoised image t0_p1.npy
# Denoised image t211_p0.npy
# Denoised image t148_p0.npy
# Denoised image t133_p1.npy
# Denoised image t68_p1.npy
# Denoised image t171_p0.npy
# Denoised image t263_p1.npy
# Denoised image t117_p1.npy
# Denoised image t115_p0.npy
# Denoised image t61_p1.npy
# Denoised image t126_p1.npy
# Denoised image t51_p1.npy
# Denoised image t15_p1.npy
# Denoised image t2_p1.npy
# Denoised image t170_p1.npy
# Denoised image t125_p1.npy
# Denoised image t82_p1.npy
# Denoised image t191_p0.npy
# Denoised image t81_p1.npy
# Denoised image t235_p0.npy
# Denoised image t239_p0.npy
# Denoised image t153_p0.npy
# Denoised image t49_p0.npy
# Denoised image t159_p0.npy
# Denoised image t247_p0.npy
# Denoised image t246_p0.npy
# Denoised image t135_p0.npy
# Denoised image t37_p1.npy
# Denoised image t209_p1.npy
# Denoised image t212_p1.npy
# Denoised image t212_p0.npy
# Denoised image t66_p1.npy
# Denoised image t147_p0.npy
# Denoised image t172_p0.npy
# Denoised image t93_p0.npy
# Denoised image t233_p0.npy
# Denoised image t96_p1.npy
# Denoised image t151_p0.npy
# Denoised image t14_p1.npy
# Denoised image t90_p1.npy
# Denoised image t135_p1.npy
# Denoised image t159_p1.npy
# Denoised image t141_p0.npy
# Denoised image t216_p0.npy
# Denoised image t189_p0.npy
# Denoised image t60_p1.npy
# Denoised image t132_p0.npy
# Denoised image t138_p0.npy
# Denoised image t72_p1.npy
# Denoised image t88_p0.npy
# Denoised image t130_p0.npy
# Denoised image t188_p0.npy
# Denoised image t213_p1.npy
# Denoised image t133_p0.npy
# Denoised image t168_p0.npy
# Denoised image t154_p1.npy
# Denoised image t204_p1.npy
# Denoised image t161_p1.npy
# Denoised image t228_p1.npy
# Denoised image t94_p0.npy
# Denoised image t91_p0.npy
# Denoised image t3_p1.npy
# Denoised image t97_p0.npy
# Denoised image t83_p1.npy
# Denoised image t158_p0.npy
# Denoised image t33_p1.npy
# Denoised image t48_p1.npy
# Denoised image t26_p1.npy
# Denoised image t254_p1.npy
# Denoised image t242_p1.npy
# Denoised image t100_p0.npy
# Denoised image t192_p0.npy
# Denoised image t30_p1.npy
# Denoised image t51_p0.npy
# Denoised image t195_p1.npy
# Denoised image t145_p1.npy
# Denoised image t21_p0.npy
# Denoised image t259_p0.npy
# Denoised image t146_p0.npy
# Denoised image t123_p1.npy
# Denoised image t79_p1.npy
# Denoised image t76_p0.npy
# Denoised image t140_p1.npy
# Denoised image t52_p1.npy
# Denoised image t116_p1.npy
# Denoised image t205_p1.npy
# Denoised image t243_p1.npy
# Denoised image t118_p0.npy
# Denoised image t20_p1.npy
# Denoised image t205_p0.npy
# Denoised image t103_p1.npy
# Denoised image t144_p1.npy
# Denoised image t89_p0.npy
# Denoised image t253_p0.npy
# Denoised image t175_p0.npy
# Denoised image t174_p1.npy
# Denoised image t74_p1.npy
# Denoised image t155_p0.npy
# Denoised image t137_p1.npy
# Denoised image t234_p1.npy
# Denoised image t105_p1.npy
# Denoised image t46_p1.npy
# Denoised image t65_p0.npy
# Denoised image t139_p0.npy
# Denoised image t58_p0.npy
# Denoised image t203_p1.npy
# Denoised image t160_p0.npy
# Denoised image t216_p1.npy
# Denoised image t118_p1.npy
# Denoised image t248_p1.npy
# Denoised image t103_p0.npy
# Denoised image t16_p1.npy
# Denoised image t215_p0.npy
# Denoised image t71_p1.npy
# Denoised image t98_p1.npy
# Denoised image t67_p1.npy
# Denoised image t155_p1.npy
# Denoised image t229_p1.npy
# Denoised image t223_p0.npy
# Denoised image t202_p0.npy
# Denoised image t237_p1.npy
# Denoised image t162_p1.npy
# Denoised image t87_p1.npy
# Denoised image t194_p0.npy
# Denoised image t250_p0.npy
# Denoised image t236_p0.npy
# Denoised image t151_p1.npy
# Denoised image t227_p0.npy
# Denoised image t143_p1.npy
# Denoised image t46_p0.npy
# Denoised image t70_p0.npy
# Denoised image t225_p1.npy
# Denoised image t206_p1.npy
# Denoised image t259_p1.npy
# Denoised image t112_p0.npy
# Denoised image t67_p0.npy
# Denoised image t213_p0.npy
# Denoised image t134_p0.npy
# Denoised image t20_p0.npy
# Denoised image t119_p0.npy
# Denoised image t25_p1.npy
# Denoised image t17_p1.npy
# Denoised image t193_p0.npy
# Denoised image t248_p0.npy
# Denoised image t12_p1.npy
# Denoised image t207_p0.npy
# Denoised image t29_p0.npy
# Denoised image t148_p1.npy
# Denoised image t192_p1.npy
# Denoised image t40_p1.npy
# Denoised image t71_p0.npy
# Denoised image t207_p1.npy
# Denoised image t106_p0.npy
# Denoised image t237_p0.npy
# Denoised image t170_p0.npy
# Denoised image t126_p0.npy
# Denoised image t119_p1.npy
# Denoised image t101_p0.npy
# Denoised image t66_p0.npy
# Denoised image t98_p0.npy
# Denoised image t245_p1.npy
# Denoised image t220_p0.npy
# Denoised image t238_p0.npy
# Denoised image t257_p1.npy
# Denoised image t230_p1.npy
# Denoised image t27_p1.npy
# Denoised image t201_p1.npy
# Denoised image t99_p1.npy
# Denoised image t240_p1.npy
# Denoised image t111_p1.npy
# Denoised image t30_p0.npy
# Denoised image t121_p0.npy
# Denoised image t154_p0.npy
# Denoised image t56_p1.npy
# Denoised image t127_p0.npy
# Denoised image t203_p0.npy
# Denoised image t34_p0.npy
# Denoised image t5_p1.npy
# Denoised image t23_p0.npy
# Denoised image t86_p1.npy
# Denoised image t211_p1.npy
# Denoised image t258_p1.npy
# Denoised image t121_p1.npy
# Denoised image t95_p1.npy
# Denoised image t65_p1.npy
# Denoised image t122_p1.npy
# Denoised image t13_p0.npy
# Denoised image t78_p0.npy
# Denoised image t167_p1.npy
# Denoised image t125_p0.npy
# Denoised image t145_p0.npy
# Denoised image t36_p1.npy
# Denoised image t222_p0.npy
# Denoised image t138_p1.npy
# Denoised image t244_p1.npy
# Denoised image t178_p1.npy
# Denoised image t7_p1.npy
# Denoised image t9_p0.npy
# Denoised image t19_p1.npy
# Denoised image t23_p1.npy
# Denoised image t124_p1.npy
# Denoised image t186_p0.npy
# Denoised image t196_p0.npy
# Denoised image t234_p0.npy
# Denoised image t12_p0.npy
# Denoised image t4_p0.npy
# Denoised image t122_p0.npy
# Denoised image t210_p0.npy
# Denoised image t69_p0.npy
# Denoised image t2_p0.npy
# Denoised image t113_p0.npy
# Denoised image t160_p1.npy
# Denoised image t251_p1.npy
# Denoised image t111_p0.npy
# Denoised image t185_p1.npy
# Denoised image t91_p1.npy
# Denoised image t194_p1.npy
# Denoised image t181_p1.npy
# Denoised image t109_p0.npy
# Denoised image t260_p1.npy
# Denoised image t223_p1.npy
# Denoised image t128_p1.npy
# Denoised image t218_p1.npy
# Denoised image t54_p1.npy
# Denoised image t219_p0.npy
# Denoised image t59_p0.npy
# Denoised image t256_p0.npy
# Denoised image t117_p0.npy
# Denoised image t28_p1.npy
# Denoised image t182_p1.npy
# Denoised image t153_p1.npy
# Denoised image t193_p1.npy
# Denoised image t24_p1.npy
# Denoised image t152_p0.npy
# Denoised image t114_p1.npy
# Denoised image t198_p0.npy
# Denoised image t9_p1.npy
# Denoised image t15_p0.npy
# Denoised image t191_p1.npy
# Denoised image t247_p1.npy
# Denoised image t150_p0.npy
# Denoised image t173_p0.npy
# Denoised image t102_p0.npy
# Denoised image t242_p0.npy
# Denoised image t41_p1.npy
# Denoised image t188_p1.npy
# Denoised image t146_p1.npy
# Denoised image t134_p1.npy
# Denoised image t114_p0.npy
# Denoised image t241_p1.npy
# Denoised image t164_p1.npy
# Denoised image t229_p0.npy
# Denoised image t236_p1.npy
# Denoised image t43_p0.npy
# Denoised image t62_p1.npy
# Denoised image t45_p0.npy
# Denoised image t262_p1.npy
# Denoised image t107_p0.npy
# Denoised image t165_p1.npy
# Denoised image t81_p0.npy
# Denoised image t59_p1.npy
# Denoised image t157_p1.npy
# Denoised image t221_p0.npy
# Denoised image t102_p1.npy
# Denoised image t180_p0.npy
# Denoised image t42_p0.npy
# Denoised image t190_p1.npy
# Denoised image t22_p1.npy
# Denoised image t107_p1.npy
# Denoised image t152_p1.npy
# Denoised image t214_p0.npy
# Denoised image t202_p1.npy
# Denoised image t196_p1.npy
# Denoised image t72_p0.npy
# Denoised image t165_p0.npy
# Denoised image t264_p0.npy
# Denoised image t149_p0.npy
# Denoised image t140_p0.npy
# Denoised image t4_p1.npy
# Denoised image t208_p0.npy
# Denoised image t63_p1.npy
# Denoised image t225_p0.npy
# Denoised image t175_p1.npy
# Denoised image t31_p1.npy
# Denoised image t184_p0.npy
# Denoised image t226_p0.npy
# Denoised image t230_p0.npy
# Denoised image t201_p0.npy
# Denoised image t184_p1.npy
# Denoised image t6_p1.npy
# Denoised image t76_p1.npy
# Denoised image t39_p0.npy
# Denoised image t173_p1.npy
# Denoised image t243_p0.npy
# Denoised image t11_p1.npy
# Denoised image t187_p0.npy
# Denoised image t42_p1.npy
# Denoised image t137_p0.npy
# Denoised image t48_p0.npy
# Denoised image t1_p0.npy
# Denoised image t68_p0.npy
# Denoised image t200_p1.npy
# Denoised image t127_p1.npy
# Denoised image t6_p0.npy
# Denoised image t232_p1.npy
# Denoised image t174_p0.npy
# Denoised image t199_p0.npy
# Denoised image t74_p0.npy
# Denoised image t100_p1.npy
# Denoised image t47_p0.npy
# Denoised image t224_p1.npy
# Denoised image t56_p0.npy
# Denoised image t177_p1.npy
# Denoised image t221_p1.npy
# Denoised image t105_p0.npy
# Denoised image t70_p1.npy
# Denoised image t240_p0.npy
# Denoised image t252_p1.npy
# Denoised image t57_p1.npy
# Denoised image t112_p1.npy
# Denoised image t69_p1.npy
# Denoised image t85_p1.npy
# Denoised image t181_p0.npy
# Denoised image t162_p0.npy
# Denoised image t38_p1.npy
# Denoised image t161_p0.npy
# Denoised image t260_p0.npy
# Denoised image t204_p0.npy
# Denoised image t90_p0.npy
# Denoised image t220_p1.npy
# Denoised image t183_p0.npy
# Denoised image t50_p1.npy
# Denoised image t50_p0.npy
# Denoised image t39_p1.npy
# Denoised image t8_p0.npy
# Denoised image t208_p1.npy
# Denoised image t82_p0.npy
# Denoised image t58_p1.npy
# Denoised image t228_p0.npy
# Denoised image t18_p1.npy
# Denoised image t21_p1.npy
# Denoised image t63_p0.npy
# Denoised image t249_p1.npy
# Denoised image t55_p1.npy
# Denoised image t60_p0.npy
# Denoised image t113_p1.npy
# Denoised image t86_p0.npy
# Denoised image t5_p0.npy
# Denoised image t116_p0.npy
# Denoised image t57_p0.npy
# Denoised image t235_p1.npy
# Denoised image t131_p1.npy
# Denoised image t206_p0.npy
# Denoised image t255_p0.npy
# Denoised image t178_p0.npy
# Denoised image t124_p0.npy
# Denoised image t44_p0.npy
# Denoised image t255_p1.npy
# Denoised image t80_p1.npy
# Denoised image t176_p1.npy
# Denoised image t109_p1.npy
# Denoised image t84_p1.npy
# Denoised image t231_p0.npy
# Denoised image t106_p1.npy
# Denoised image t166_p1.npy
# Denoised image t246_p1.npy
# Denoised image t239_p1.npy
# Denoised image t52_p0.npy
# Denoised image t252_p0.npy
# Denoised image t108_p1.npy
# Denoised image t249_p0.npy
# Denoised image t128_p0.npy
# Denoised image t80_p0.npy
# Denoised image t130_p1.npy
# Denoised image t1_p1.npy
# Denoised image t123_p0.npy
# Denoised image t197_p1.npy
# Denoised image t217_p0.npy
# Denoised image t136_p1.npy
# Denoised image t179_p0.npy
# Denoised image t182_p0.npy
# Denoised image t78_p1.npy
# Denoised image t35_p1.npy
# Denoised image t245_p0.npy
# Denoised image t104_p0.npy
# Denoised image t49_p1.npy
# Denoised image t3_p0.npy
# Denoised image t95_p0.npy
